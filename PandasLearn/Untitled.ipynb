# %%
from sqlalchemy import create_engine
import pandas as pd

oracle_connection = create_engine( "oracle+cx_oracle://sys:Admin@localhost:1521/orcl?mode=SYSDBA")
sql_query = """select *from emp"""
df = pd.read_sql(sql_query,oracle_connection)

# %%
df
# Out:
#     empno   ename        job     mgr   hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000.0     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850.0     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-06-09  2450.0     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-02  2975.0     NaN      20
# 4    7788   SCOTT    ANALYST  7566.0 1987-04-19  3000.0     NaN      20
# 5    7902    FORD    ANALYST  7566.0 1981-12-03  3000.0     NaN      20
# 6    7369   SMITH      CLERK  7902.0 1980-12-17   800.0     NaN      20
# 7    7499   ALLEN   SALESMAN  7698.0 1981-02-20  1600.0   300.0      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-22  1250.0   500.0      30
# 9    7654  MARTIN   SALESMAN  7698.0 1981-09-28  1250.0  1400.0      30
# 10   7844  TURNER   SALESMAN  7698.0 1981-09-08  1500.0     0.0      30
# 11   7876   ADAMS      CLERK  7788.0 1987-05-23  1100.0     NaN      20
# ...

# %%
import pandas as pd

# %%
 data = {'Category': ['A', 'B', 'A', 'B', 'A'],
 'Values': [10, 20, 30, 40, 50]}

# %%
data
# Out:
# {'Category': ['A', 'B', 'A', 'B', 'A'], 'Values': [10, 20, 30, 40, 50]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50

# %%
 grouped = df.groupby('Category')['Values'].sum()

# %%
print(grouped)
# Out:
# Category
# A    90
# B    60
# Name: Values, dtype: int64

# %%
 import pandas as pd

# %%
 data = {'Category': ['A', 'B', 'A', 'B', 'A'],
 'Type': ['X', 'X', 'Y', 'Y', 'Y'],
 'Values': [10, 20, 30, 40, 50]}

# %%
 df = pd.DataFrame(data)

# %%
df
# Out:
#   Category Type  Values
# 0        A    X      10
# 1        B    X      20
# 2        A    Y      30
# 3        B    Y      40
# 4        A    Y      50

# %%
grouped = df.groupby('Category','type')['Values'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(cls, axis)
#     576             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     577         except KeyError:
# --> 578             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# KeyError: 'type'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11872\216150239.py in ?()
# ----> 1 grouped = df.groupby('Category','type')['Values'].sum()
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9156         observed: bool | lib.NoDefault = lib.no_default,
#    9157         dropna: bool = True,
# ...

# %%
 grouped = df.groupby(['Category', 'Type'])['Values'].sum()

# %%
grouped
# Out:
# Category  Type
# A         X       10
#           Y       80
# B         X       20
#           Y       40
# Name: Values, dtype: int64

# %%
import pandas as pd

# %%
 data = {'Category': ['A', 'B', 'A', 'B', 'A'],
 'Values': [10, 20, 30, 40, 50]}

# %%
 df = pd.DataFrame(data)

# %%
df
# Out:
#   Category  Values
# 0        A      10
# 1        B      20
# 2        A      30
# 3        B      40
# 4        A      50

# %%
 grouped = df.groupby('Category')['Values'].agg(['sum', 'mean'])

# %%
grouped
# Out:
#           sum  mean
# Category
# A          90  30.0
# B          60  30.0

# %%
from sqlalchemy import create_engine
import pandas as pd

oracle_connection = create_engine( "oracle+cx_oracle://sys:Admin@localhost:1521/orcl?mode=SYSDBA")
sql_query = """select *from emp"""
df = pd.read_sql(sql_query,oracle_connection)

# %%
df
# Out:
#     empno   ename        job     mgr   hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000.0     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850.0     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-06-09  2450.0     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-02  2975.0     NaN      20
# 4    7788   SCOTT    ANALYST  7566.0 1987-04-19  3000.0     NaN      20
# 5    7902    FORD    ANALYST  7566.0 1981-12-03  3000.0     NaN      20
# 6    7369   SMITH      CLERK  7902.0 1980-12-17   800.0     NaN      20
# 7    7499   ALLEN   SALESMAN  7698.0 1981-02-20  1600.0   300.0      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-22  1250.0   500.0      30
# 9    7654  MARTIN   SALESMAN  7698.0 1981-09-28  1250.0  1400.0      30
# 10   7844  TURNER   SALESMAN  7698.0 1981-09-08  1500.0     0.0      30
# 11   7876   ADAMS      CLERK  7788.0 1987-05-23  1100.0     NaN      20
# ...

# %%
   df_agg = df.groupby(['deptno','salary'])['salary'].agg(['sum','max','min','count'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_agg = df.groupby(['deptno','salary'])['salary'].agg(['sum','max','min','count'])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("emp.csv")

# %%
df
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 2       8    Sagar    1000      20  2020-11-30
# 3       4   Thomas    1000      10  2019-08-18
# 4       5     Jade    2000      10  2021-02-10
# 5       6    Smith    1000      10  2016-12-01
# 6       7   Robert    3000      20  2023-06-25
# 7       3     Nick    1000      30  2015-09-15
# 8       9    Naman    4000      30  2020-01-20
# 9       1    Vikas    1000      30  2017-10-03
# 10     11   Dennis   41000      30  2024-01-05
# 11     12    Karan    2200      20  2018-06-16
# 12     13   Simran    1500      10  2019-12-19
# 13     14     Amit    2000      30  2022-04-09
# 14     15     Neha    1700      20  2021-07-22
# 15     16    Rahul    1200      10  2016-03-28
# 16     17    Divya    3000      30  2015-11-11
# 17     18   Rakesh    1800      10  2020-09-04
# 18     19   Monica    2500      20  2023-08-07
# ...

# %%
 df_agg = df.groupby(['deptno','salary'])['salary'].agg(['sum','max','min','count'])

# %%
# Out:
#                  sum    max    min  count
# deptno salary
# 10     1000     4000   1000   1000      4
#        1100     1100   1100   1100      1
#        1200     1200   1200   1200      1
#        1300     1300   1300   1300      1
#        1500     1500   1500   1500      1
#        1600     1600   1600   1600      1
#        1800     3600   1800   1800      2
#        1900     1900   1900   1900      1
#        2000     2000   2000   2000      1
#        2100     2100   2100   2100      1
#        2200     2200   2200   2200      1
#        2700     5400   2700   2700      2
#        3000     3000   3000   3000      1
# 20     1000     2000   1000   1000      2
#        1200     1200   1200   1200      1
#        1600     1600   1600   1600      1
#        1700     1700   1700   1700      1
#        1800     1800   1800   1800      1
#        1900     1900   1900   1900      1
#        2000     4000   2000   2000      2
#        2200     2200   2200   2200      1
# ...

# %%
 df= df.sort_values(by=['salary'])

# %%
df
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 2       8    Sagar    1000      20  2020-11-30
# 3       4   Thomas    1000      10  2019-08-18
# 5       6    Smith    1000      10  2016-12-01
# 7       3     Nick    1000      30  2015-09-15
# 9       1    Vikas    1000      30  2017-10-03
# 21     22    David    1000      20  2017-02-17
# 29     30   Suresh    1100      10  2018-09-09
# 28     29    Priya    1200      20  2023-02-11
# 15     16    Rahul    1200      10  2016-03-28
# 27     28    Mohan    1300      10  2015-04-17
# 26     27   Kavita    1400      30  2019-01-06
# 12     13   Simran    1500      10  2019-12-19
# 22     23    Anita    1500      30  2019-05-21
# 25     26    Harsh    1600      10  2021-09-25
# 46     47    Payal    1600      20  2015-10-10
# 14     15     Neha    1700      20  2021-07-22
# 45     46    Manoj    1700      30  2019-07-24
# ...

# %%
df= df.sort_values(by=['salary','deptno'])

# %%
df
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 3       4   Thomas    1000      10  2019-08-18
# 5       6    Smith    1000      10  2016-12-01
# 2       8    Sagar    1000      20  2020-11-30
# 21     22    David    1000      20  2017-02-17
# 7       3     Nick    1000      30  2015-09-15
# 9       1    Vikas    1000      30  2017-10-03
# 29     30   Suresh    1100      10  2018-09-09
# 15     16    Rahul    1200      10  2016-03-28
# 28     29    Priya    1200      20  2023-02-11
# 27     28    Mohan    1300      10  2015-04-17
# 26     27   Kavita    1400      30  2019-01-06
# 12     13   Simran    1500      10  2019-12-19
# 22     23    Anita    1500      30  2019-05-21
# 25     26    Harsh    1600      10  2021-09-25
# 46     47    Payal    1600      20  2015-10-10
# 14     15     Neha    1700      20  2021-07-22
# 45     46    Manoj    1700      30  2019-07-24
# ...

# %%
 df= df.sort_values(by=['salary','deptno'],ascending=[True,True])

# %%
df
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 3       4   Thomas    1000      10  2019-08-18
# 5       6    Smith    1000      10  2016-12-01
# 2       8    Sagar    1000      20  2020-11-30
# 21     22    David    1000      20  2017-02-17
# 7       3     Nick    1000      30  2015-09-15
# 9       1    Vikas    1000      30  2017-10-03
# 29     30   Suresh    1100      10  2018-09-09
# 15     16    Rahul    1200      10  2016-03-28
# 28     29    Priya    1200      20  2023-02-11
# 27     28    Mohan    1300      10  2015-04-17
# 26     27   Kavita    1400      30  2019-01-06
# 12     13   Simran    1500      10  2019-12-19
# 22     23    Anita    1500      30  2019-05-21
# 25     26    Harsh    1600      10  2021-09-25
# 46     47    Payal    1600      20  2015-10-10
# 14     15     Neha    1700      20  2021-07-22
# 45     46    Manoj    1700      30  2019-07-24
# ...

# %%
df=  df.sort_values(by=['salary','deptno'],ascending=[True,False])

# %%
df
# Out:
#       eno    ename  salary  deptno         doj
# 7       3     Nick    1000      30  2015-09-15
# 9       1    Vikas    1000      30  2017-10-03
# 2       8    Sagar    1000      20  2020-11-30
# 21     22    David    1000      20  2017-02-17
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 3       4   Thomas    1000      10  2019-08-18
# 5       6    Smith    1000      10  2016-12-01
# 29     30   Suresh    1100      10  2018-09-09
# 28     29    Priya    1200      20  2023-02-11
# 15     16    Rahul    1200      10  2016-03-28
# 27     28    Mohan    1300      10  2015-04-17
# 26     27   Kavita    1400      30  2019-01-06
# 22     23    Anita    1500      30  2019-05-21
# 12     13   Simran    1500      10  2019-12-19
# 46     47    Payal    1600      20  2015-10-10
# 25     26    Harsh    1600      10  2021-09-25
# 45     46    Manoj    1700      30  2019-07-24
# 14     15     Neha    1700      20  2021-07-22
# ...

# %%
 import pandas as pd

# %%
 df = pd.read_csv("emp.csv")

# %%
df
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 2       8    Sagar    1000      20  2020-11-30
# 3       4   Thomas    1000      10  2019-08-18
# 4       5     Jade    2000      10  2021-02-10
# 5       6    Smith    1000      10  2016-12-01
# 6       7   Robert    3000      20  2023-06-25
# 7       3     Nick    1000      30  2015-09-15
# 8       9    Naman    4000      30  2020-01-20
# 9       1    Vikas    1000      30  2017-10-03
# 10     11   Dennis   41000      30  2024-01-05
# 11     12    Karan    2200      20  2018-06-16
# 12     13   Simran    1500      10  2019-12-19
# 13     14     Amit    2000      30  2022-04-09
# 14     15     Neha    1700      20  2021-07-22
# 15     16    Rahul    1200      10  2016-03-28
# 16     17    Divya    3000      30  2015-11-11
# 17     18   Rakesh    1800      10  2020-09-04
# 18     19   Monica    2500      20  2023-08-07
# ...

# %%
  df.sort_index(ascending = True)
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 2       8    Sagar    1000      20  2020-11-30
# 3       4   Thomas    1000      10  2019-08-18
# 4       5     Jade    2000      10  2021-02-10
# 5       6    Smith    1000      10  2016-12-01
# 6       7   Robert    3000      20  2023-06-25
# 7       3     Nick    1000      30  2015-09-15
# 8       9    Naman    4000      30  2020-01-20
# 9       1    Vikas    1000      30  2017-10-03
# 10     11   Dennis   41000      30  2024-01-05
# 11     12    Karan    2200      20  2018-06-16
# 12     13   Simran    1500      10  2019-12-19
# 13     14     Amit    2000      30  2022-04-09
# 14     15     Neha    1700      20  2021-07-22
# 15     16    Rahul    1200      10  2016-03-28
# 16     17    Divya    3000      30  2015-11-11
# 17     18   Rakesh    1800      10  2020-09-04
# 18     19   Monica    2500      20  2023-08-07
# ...

# %%
 df.sort_index(ascending=False)
# Out:
#       eno    ename  salary  deptno         doj
# 46     47    Payal    1600      20  2015-10-10
# 45     46    Manoj    1700      30  2019-07-24
# 44     45  Sanjana    1800      20  2023-03-17
# 43     44    Ashok    1900      10  2016-06-08
# 42     43    Geeta    2100      30  2017-11-14
# 41     42    Tarun    2200      10  2021-01-09
# 40     41     Nina    2300      20  2018-12-28
# 39     40     Yash    2500      30  2020-07-19
# 38     39   Poonam    2600      20  2022-02-05
# 37     38     Alok    2700      10  2019-03-02
# 36     37    Kunal    2800      30  2015-08-22
# 35     36     Ritu    3200      20  2023-05-01
# 34     35    Seema    3000      10  2021-10-15
# 33     34    Vivek    2000      20  2017-07-31
# 32     33    Nidhi    2400      30  2016-05-12
# 31     32     Ajay    2100      10  2020-06-26
# 30     31     Rani    1900      20  2022-11-03
# 29     30   Suresh    1100      10  2018-09-09
# 28     29    Priya    1200      20  2023-02-11
# ...

# %%
 emp_count_by_deptno = df.groupby('deptno')['ename'].count().reset_index()

# %%
df = pd.DataFrame('emp.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11872\1976592376.py in ?()
# ----> 1 df = pd.DataFrame('emp.csv')
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, data, index, columns, dtype, copy)
#     882                 )
#     883         # For data is scalar
#     884         else:
#     885             if index is None or columns is None:
# --> 886                 raise ValueError("DataFrame constructor not properly called!")
#     887
#     888             index = ensure_index(index)
#     889             columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
df = pd.read_csv("emp.csv")

# %%
emp_count_by_deptno = df.groupby('deptno')['ename'].count().reset_index()

# %%
emp_count_by_deptno
# Out:
#    deptno  ename
# 0      10     18
# 1      20     15
# 2      30     14

# %%
filtered_df = df[df['salary'] < 10000]

# %%
filtered_df
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 2       8    Sagar    1000      20  2020-11-30
# 3       4   Thomas    1000      10  2019-08-18
# 4       5     Jade    2000      10  2021-02-10
# 5       6    Smith    1000      10  2016-12-01
# 6       7   Robert    3000      20  2023-06-25
# 7       3     Nick    1000      30  2015-09-15
# 8       9    Naman    4000      30  2020-01-20
# 9       1    Vikas    1000      30  2017-10-03
# 11     12    Karan    2200      20  2018-06-16
# 12     13   Simran    1500      10  2019-12-19
# 13     14     Amit    2000      30  2022-04-09
# 14     15     Neha    1700      20  2021-07-22
# 15     16    Rahul    1200      10  2016-03-28
# 16     17    Divya    3000      30  2015-11-11
# 17     18   Rakesh    1800      10  2020-09-04
# 18     19   Monica    2500      20  2023-08-07
# 19     20     John    2300      30  2018-10-29
# ...

# %%
 total_saalries_by_deptno_salLessThan10000 = filtered_df.groupby('deptno')
 ['salary'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 2
#       1 total_saalries_by_deptno_salLessThan10000 = filtered_df.groupby('deptno')
# ----> 2 ['salary'].sum().reset_index()
#
# AttributeError: 'list' object has no attribute 'sum'

# %%
 Filtered_df = (df['deptno'] == 10) | (df['deptno'] == 20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Filtered_df = (df['deptno'] == 10) | (df['deptno'] == 20)
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("emp.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("emp.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
df = pd.read_csv("emp.csv")

# %%
df
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 2       8    Sagar    1000      20  2020-11-30
# 3       4   Thomas    1000      10  2019-08-18
# 4       5     Jade    2000      10  2021-02-10
# 5       6    Smith    1000      10  2016-12-01
# 6       7   Robert    3000      20  2023-06-25
# 7       3     Nick    1000      30  2015-09-15
# 8       9    Naman    4000      30  2020-01-20
# 9       1    Vikas    1000      30  2017-10-03
# 10     11   Dennis   41000      30  2024-01-05
# 11     12    Karan    2200      20  2018-06-16
# 12     13   Simran    1500      10  2019-12-19
# 13     14     Amit    2000      30  2022-04-09
# 14     15     Neha    1700      20  2021-07-22
# 15     16    Rahul    1200      10  2016-03-28
# 16     17    Divya    3000      30  2015-11-11
# 17     18   Rakesh    1800      10  2020-09-04
# 18     19   Monica    2500      20  2023-08-07
# ...

# %%
 Filtered_df = (df['deptno'] == 10) | (df['deptno'] == 20)

# %%
from sqlalchemy import create_engine
import pandas as pd

oracle_connection = create_engine( "oracle+cx_oracle://sys:Admin@localhost:1521/orcl?mode=SYSDBA")
sql_query = """select *from emp"""
df1 = pd.read_sql(sql_query,oracle_connection)

# %%
df1
# Out:
#     empno   ename        job     mgr   hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000.0     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850.0     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-06-09  2450.0     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-02  2975.0     NaN      20
# 4    7788   SCOTT    ANALYST  7566.0 1987-04-19  3000.0     NaN      20
# 5    7902    FORD    ANALYST  7566.0 1981-12-03  3000.0     NaN      20
# 6    7369   SMITH      CLERK  7902.0 1980-12-17   800.0     NaN      20
# 7    7499   ALLEN   SALESMAN  7698.0 1981-02-20  1600.0   300.0      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-22  1250.0   500.0      30
# 9    7654  MARTIN   SALESMAN  7698.0 1981-09-28  1250.0  1400.0      30
# 10   7844  TURNER   SALESMAN  7698.0 1981-09-08  1500.0     0.0      30
# 11   7876   ADAMS      CLERK  7788.0 1987-05-23  1100.0     NaN      20
# ...

# %%
df2 = pd.read_csv("emp.csv")

# %%
df2
# Out:
#       eno    ename  salary  deptno         doj
# 0      10    Amber    1000      10  2018-05-14
# 1       2     Amar    1000      10  2017-03-22
# 2       8    Sagar    1000      20  2020-11-30
# 3       4   Thomas    1000      10  2019-08-18
# 4       5     Jade    2000      10  2021-02-10
# 5       6    Smith    1000      10  2016-12-01
# 6       7   Robert    3000      20  2023-06-25
# 7       3     Nick    1000      30  2015-09-15
# 8       9    Naman    4000      30  2020-01-20
# 9       1    Vikas    1000      30  2017-10-03
# 10     11   Dennis   41000      30  2024-01-05
# 11     12    Karan    2200      20  2018-06-16
# 12     13   Simran    1500      10  2019-12-19
# 13     14     Amit    2000      30  2022-04-09
# 14     15     Neha    1700      20  2021-07-22
# 15     16    Rahul    1200      10  2016-03-28
# 16     17    Divya    3000      30  2015-11-11
# 17     18   Rakesh    1800      10  2020-09-04
# 18     19   Monica    2500      20  2023-08-07
# ...

# %%
df1
# Out:
#     empno   ename        job     mgr   hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000.0     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850.0     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-06-09  2450.0     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-02  2975.0     NaN      20
# 4    7788   SCOTT    ANALYST  7566.0 1987-04-19  3000.0     NaN      20
# 5    7902    FORD    ANALYST  7566.0 1981-12-03  3000.0     NaN      20
# 6    7369   SMITH      CLERK  7902.0 1980-12-17   800.0     NaN      20
# 7    7499   ALLEN   SALESMAN  7698.0 1981-02-20  1600.0   300.0      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-22  1250.0   500.0      30
# 9    7654  MARTIN   SALESMAN  7698.0 1981-09-28  1250.0  1400.0      30
# 10   7844  TURNER   SALESMAN  7698.0 1981-09-08  1500.0     0.0      30
# 11   7876   ADAMS      CLERK  7788.0 1987-05-23  1100.0     NaN      20
# ...

# %%
 df1.merge(df2,on='deptno',how='inner')
# Out:
#      empno ename_x        job     mgr   hiredate     sal  comm  deptno    eno  \
# 0     7839    KING  PRESIDENT     NaN 1981-11-17  5000.0   NaN      10     10
# 1     7839    KING  PRESIDENT     NaN 1981-11-17  5000.0   NaN      10      2
# 2     7839    KING  PRESIDENT     NaN 1981-11-17  5000.0   NaN      10      4
# 3     7839    KING  PRESIDENT     NaN 1981-11-17  5000.0   NaN      10      5
# 4     7839    KING  PRESIDENT     NaN 1981-11-17  5000.0   NaN      10      6
# ..     ...     ...        ...     ...        ...     ...   ...     ...    ...
# 208   7934  MILLER      CLERK  7782.0 1982-01-23  1300.0   NaN      10     32
# 209   7934  MILLER      CLERK  7782.0 1982-01-23  1300.0   NaN      10     35
# 210   7934  MILLER      CLERK  7782.0 1982-01-23  1300.0   NaN      10     38
# 211   7934  MILLER      CLERK  7782.0 1982-01-23  1300.0   NaN      10     42
# 212   7934  MILLER      CLERK  7782.0 1982-01-23  1300.0   NaN      10     44
#
#     ename_y  salary         doj
# ...
