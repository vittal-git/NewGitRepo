# %%
import pandas as pd

df1 = pd.read_csv('emp.csv')

# %%
df1
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
import pandas as pd

df2 = pd.read_csv('emp1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 df2 = pd.read_csv('emp1.csv')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df1
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
import pandas as pd

df2 = pd.read_csv('emp1.csv')

# %%
df2
# Out:
#     eeno           ename
# 0   1001     Aarav Mehta
# 1   1002     Isha Sharma
# 2   1003      Rajiv Nair
# 3   1004     Kavya Reddy
# 4   1005    Aditya Patel
# 5   1006      Priya Iyer
# 6   1007     Arjun Singh
# 7   1008      Neha Verma
# 8   1009   Devansh Desai
# 9   1010    Ananya Joshi
# 10  1011    Rohan Kapoor
# 11  1012     Simran Kaur
# 12  1013      Ayan Dutta
# 13  1014    Tanya Bansal
# 14  1015  Manav Malhotra
# 15  2001      Shruti Rao
# 16  2002     Kunal Dixit
# 17  2003     Sanya Dubey
# 18  2010    Harshit Jain
# 19  2011    Ritika Ghosh

# %%
df1.merge(df2,on='eno',how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14928\1628248623.py in ?()
# ----> 1 df1.merge(df2,on='eno',how='inner')
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
# ...

# %%
df1.merge(df2,on='eno',how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14928\1628248623.py in ?()
# ----> 1 df1.merge(df2,on='eno',how='inner')
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
# ...

# %%
df1.merge(df2,on='eno',how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14928\1628248623.py in ?()
# ----> 1 df1.merge(df2,on='eno',how='inner')
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10828         validate: MergeValidate | None = None,
#   10829     ) -> DataFrame:
#   10830         from pandas.core.reshape.merge import merge
#   10831
# > 10832         return merge(
#   10833             self,
#   10834             right,
#   10835             how=how,
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
# ...

# %%
import pandas as pd

df2 = pd.read_csv('emp1.csv')

# %%
df2
# Out:
#      eno           ename
# 0   1001     Aarav Mehta
# 1   1002     Isha Sharma
# 2   1003      Rajiv Nair
# 3   1004     Kavya Reddy
# 4   1005    Aditya Patel
# 5   1006      Priya Iyer
# 6   1007     Arjun Singh
# 7   1008      Neha Verma
# 8   1009   Devansh Desai
# 9   1010    Ananya Joshi
# 10  1011    Rohan Kapoor
# 11  1012     Simran Kaur
# 12  1013      Ayan Dutta
# 13  1014    Tanya Bansal
# 14  1015  Manav Malhotra
# 15  2001      Shruti Rao
# 16  2002     Kunal Dixit
# 17  2003     Sanya Dubey
# 18  2010    Harshit Jain
# 19  2011    Ritika Ghosh

# %% [markdown]
# df3

# %%
df1.merge(df2,on='eno',how='inner')
# Out:
#      eno         ename_x         doj  deptno  salary         ename_y
# 0   1001    Arjun Sharma  2022-01-15      10    1000     Aarav Mehta
# 1   1002     Priya Patel  2023-03-22      20   67387     Isha Sharma
# 2   1003      Ravi Kumar  2021-05-10      30   70421      Rajiv Nair
# 3   1004     Sneha Gupta  2020-08-25      40   68902     Kavya Reddy
# 4   1005      Anil Reddy  2024-02-13      50   78005    Aditya Patel
# 5   1006      Neha Verma  2019-11-30      60   59843      Priya Iyer
# 6   1007     Vijay Singh  2022-07-08      10    1000     Arjun Singh
# 7   1008     Ananya Iyer  2021-03-15      20   74625      Neha Verma
# 8   1009    Manish Joshi  2020-12-19      30   67560   Devansh Desai
# 9   1010     Simran Kaur  2023-01-11      40   68902    Ananya Joshi
# 10  1011    Rajesh Mehta  2021-09-01      50   62497    Rohan Kapoor
# 11  1012   Deepika Desai  2020-06-10      60   70179     Simran Kaur
# 12  1013  Shivani Sharma  2022-09-13      10   74363      Ayan Dutta
# ...

# %%
df3=pd.merge(df1,df2,on='eno',how='inner')

# %%
df3
# Out:
#      eno         ename_x         doj  deptno  salary         ename_y
# 0   1001    Arjun Sharma  2022-01-15      10    1000     Aarav Mehta
# 1   1002     Priya Patel  2023-03-22      20   67387     Isha Sharma
# 2   1003      Ravi Kumar  2021-05-10      30   70421      Rajiv Nair
# 3   1004     Sneha Gupta  2020-08-25      40   68902     Kavya Reddy
# 4   1005      Anil Reddy  2024-02-13      50   78005    Aditya Patel
# 5   1006      Neha Verma  2019-11-30      60   59843      Priya Iyer
# 6   1007     Vijay Singh  2022-07-08      10    1000     Arjun Singh
# 7   1008     Ananya Iyer  2021-03-15      20   74625      Neha Verma
# 8   1009    Manish Joshi  2020-12-19      30   67560   Devansh Desai
# 9   1010     Simran Kaur  2023-01-11      40   68902    Ananya Joshi
# 10  1011    Rajesh Mehta  2021-09-01      50   62497    Rohan Kapoor
# 11  1012   Deepika Desai  2020-06-10      60   70179     Simran Kaur
# 12  1013  Shivani Sharma  2022-09-13      10   74363      Ayan Dutta
# ...

# %%
import pandas as pd

df2 = pd.read_csv('emp1.csv')

# %%
df2
# Out:
#     eeno           ename
# 0   1001     Aarav Mehta
# 1   1002     Isha Sharma
# 2   1003      Rajiv Nair
# 3   1004     Kavya Reddy
# 4   1005    Aditya Patel
# 5   1006      Priya Iyer
# 6   1007     Arjun Singh
# 7   1008      Neha Verma
# 8   1009   Devansh Desai
# 9   1010    Ananya Joshi
# 10  1011    Rohan Kapoor
# 11  1012     Simran Kaur
# 12  1013      Ayan Dutta
# 13  1014    Tanya Bansal
# 14  1015  Manav Malhotra
# 15  2001      Shruti Rao
# 16  2002     Kunal Dixit
# 17  2003     Sanya Dubey
# 18  2010    Harshit Jain
# 19  2011    Ritika Ghosh

# %%
df3=df1.merge(df2,left_on='eno',right_on='eeno',how='inner')

# %%
df3
# Out:
#      eno         ename_x         doj  deptno  salary  eeno         ename_y
# 0   1001    Arjun Sharma  2022-01-15      10    1000  1001     Aarav Mehta
# 1   1002     Priya Patel  2023-03-22      20   67387  1002     Isha Sharma
# 2   1003      Ravi Kumar  2021-05-10      30   70421  1003      Rajiv Nair
# 3   1004     Sneha Gupta  2020-08-25      40   68902  1004     Kavya Reddy
# 4   1005      Anil Reddy  2024-02-13      50   78005  1005    Aditya Patel
# 5   1006      Neha Verma  2019-11-30      60   59843  1006      Priya Iyer
# 6   1007     Vijay Singh  2022-07-08      10    1000  1007     Arjun Singh
# 7   1008     Ananya Iyer  2021-03-15      20   74625  1008      Neha Verma
# 8   1009    Manish Joshi  2020-12-19      30   67560  1009   Devansh Desai
# 9   1010     Simran Kaur  2023-01-11      40   68902  1010    Ananya Joshi
# 10  1011    Rajesh Mehta  2021-09-01      50   62497  1011    Rohan Kapoor
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

oracle_connection = create_engine( "oracle+cx_oracle://sys:Admin@localhost:1521/orcl?mode=SYSDBA")
sql_query = """select *from emp"""
df = pd.read_sql(sql_query,oracle_connection)

# %%
df
# Out:
#     empno   ename        job     mgr   hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000.0     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850.0     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-06-09  2450.0     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-02  2975.0     NaN      20
# 4    7788   SCOTT    ANALYST  7566.0 1987-04-19  3000.0     NaN      20
# 5    7902    FORD    ANALYST  7566.0 1981-12-03  3000.0     NaN      20
# 6    7369   SMITH      CLERK  7902.0 1980-12-17   800.0     NaN      20
# 7    7499   ALLEN   SALESMAN  7698.0 1981-02-20  1600.0   300.0      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-22  1250.0   500.0      30
# 9    7654  MARTIN   SALESMAN  7698.0 1981-09-28  1250.0  1400.0      30
# 10   7844  TURNER   SALESMAN  7698.0 1981-09-08  1500.0     0.0      30
# 11   7876   ADAMS      CLERK  7788.0 1987-05-23  1100.0     NaN      20
# ...

# %%
validation_df = df1.[['eno']].merge(
    df[['empno']],
    left_on='eno', right_on='empno',
    how='left',
    indicator=True
)

not_loaded = validation_df[validation_df['_merge'] == 'left_only']

print("Not loaded records:")
print(not_loaded)
# Out:
#   Cell In[28], line 1
#     validation_df = df1.[['eno']].merge(
#                         ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#     empno   ename        job     mgr   hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000.0     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850.0     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-06-09  2450.0     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-02  2975.0     NaN      20
# 4    7788   SCOTT    ANALYST  7566.0 1987-04-19  3000.0     NaN      20
# 5    7902    FORD    ANALYST  7566.0 1981-12-03  3000.0     NaN      20
# 6    7369   SMITH      CLERK  7902.0 1980-12-17   800.0     NaN      20
# 7    7499   ALLEN   SALESMAN  7698.0 1981-02-20  1600.0   300.0      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-22  1250.0   500.0      30
# 9    7654  MARTIN   SALESMAN  7698.0 1981-09-28  1250.0  1400.0      30
# 10   7844  TURNER   SALESMAN  7698.0 1981-09-08  1500.0     0.0      30
# 11   7876   ADAMS      CLERK  7788.0 1987-05-23  1100.0     NaN      20
# ...

# %%
df1
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
validation_df = df1[['eno']].merge(
    df[['empno']],
    left_on='eno', right_on='empno',
    how='left',
    indicator=True
)

not_loaded = validation_df[validation_df['_merge'] == 'left_only']

print("Not loaded records:")
print(not_loaded)
# Out:
# Not loaded records:
#      eno  empno     _merge
# 0   1001    NaN  left_only
# 1   1002    NaN  left_only
# 2   1003    NaN  left_only
# 3   1004    NaN  left_only
# 4   1005    NaN  left_only
# 5   1006    NaN  left_only
# 6   1007    NaN  left_only
# 7   1008    NaN  left_only
# 8   1009    NaN  left_only
# 9   1010    NaN  left_only
# 10  1011    NaN  left_only
# 11  1012    NaN  left_only
# 12  1013    NaN  left_only
# 13  1014    NaN  left_only
# 14  1015    NaN  left_only
# 15  1016    NaN  left_only
# 16  1017    NaN  left_only
# 17  1018    NaN  left_only
# 18  1019    NaN  left_only
# 19  1020    NaN  left_only
# 20  1021    NaN  left_only
# 21  1022    NaN  left_only
# 22  1023    NaN  left_only
# 23  1024    NaN  left_only
# 24  1025    NaN  left_only
# 25  1026    NaN  left_only
# 26  1027    NaN  left_only
# 27  1028    NaN  left_only
# 28  1029    NaN  left_only
# 29  1030    NaN  left_only
# 30  1031    NaN  left_only
# 31  1032    NaN  left_only
# ...

# %%
df1
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
df2
# Out:
#     eeno           ename
# 0   1001     Aarav Mehta
# 1   1002     Isha Sharma
# 2   1003      Rajiv Nair
# 3   1004     Kavya Reddy
# 4   1005    Aditya Patel
# 5   1006      Priya Iyer
# 6   1007     Arjun Singh
# 7   1008      Neha Verma
# 8   1009   Devansh Desai
# 9   1010    Ananya Joshi
# 10  1011    Rohan Kapoor
# 11  1012     Simran Kaur
# 12  1013      Ayan Dutta
# 13  1014    Tanya Bansal
# 14  1015  Manav Malhotra
# 15  2001      Shruti Rao
# 16  2002     Kunal Dixit
# 17  2003     Sanya Dubey
# 18  2010    Harshit Jain
# 19  2011    Ritika Ghosh

# %%
df3
# Out:
#      eno         ename_x         doj  deptno  salary  eeno         ename_y
# 0   1001    Arjun Sharma  2022-01-15      10    1000  1001     Aarav Mehta
# 1   1002     Priya Patel  2023-03-22      20   67387  1002     Isha Sharma
# 2   1003      Ravi Kumar  2021-05-10      30   70421  1003      Rajiv Nair
# 3   1004     Sneha Gupta  2020-08-25      40   68902  1004     Kavya Reddy
# 4   1005      Anil Reddy  2024-02-13      50   78005  1005    Aditya Patel
# 5   1006      Neha Verma  2019-11-30      60   59843  1006      Priya Iyer
# 6   1007     Vijay Singh  2022-07-08      10    1000  1007     Arjun Singh
# 7   1008     Ananya Iyer  2021-03-15      20   74625  1008      Neha Verma
# 8   1009    Manish Joshi  2020-12-19      30   67560  1009   Devansh Desai
# 9   1010     Simran Kaur  2023-01-11      40   68902  1010    Ananya Joshi
# 10  1011    Rajesh Mehta  2021-09-01      50   62497  1011    Rohan Kapoor
# ...

# %%
df
# Out:
#     empno   ename        job     mgr   hiredate     sal    comm  deptno
# 0    7839    KING  PRESIDENT     NaN 1981-11-17  5000.0     NaN      10
# 1    7698   BLAKE    MANAGER  7839.0 1981-05-01  2850.0     NaN      30
# 2    7782   CLARK    MANAGER  7839.0 1981-06-09  2450.0     NaN      10
# 3    7566   JONES    MANAGER  7839.0 1981-04-02  2975.0     NaN      20
# 4    7788   SCOTT    ANALYST  7566.0 1987-04-19  3000.0     NaN      20
# 5    7902    FORD    ANALYST  7566.0 1981-12-03  3000.0     NaN      20
# 6    7369   SMITH      CLERK  7902.0 1980-12-17   800.0     NaN      20
# 7    7499   ALLEN   SALESMAN  7698.0 1981-02-20  1600.0   300.0      30
# 8    7521    WARD   SALESMAN  7698.0 1981-02-22  1250.0   500.0      30
# 9    7654  MARTIN   SALESMAN  7698.0 1981-09-28  1250.0  1400.0      30
# 10   7844  TURNER   SALESMAN  7698.0 1981-09-08  1500.0     0.0      30
# 11   7876   ADAMS      CLERK  7788.0 1987-05-23  1100.0     NaN      20
# ...

# %%
df=pd.concat([df1,df2],axis=1,join='inner')

# %%
df
# Out:
#      eno           ename         doj  deptno  salary  eeno           ename
# 0   1001    Arjun Sharma  2022-01-15      10    1000  1001     Aarav Mehta
# 1   1002     Priya Patel  2023-03-22      20   67387  1002     Isha Sharma
# 2   1003      Ravi Kumar  2021-05-10      30   70421  1003      Rajiv Nair
# 3   1004     Sneha Gupta  2020-08-25      40   68902  1004     Kavya Reddy
# 4   1005      Anil Reddy  2024-02-13      50   78005  1005    Aditya Patel
# 5   1006      Neha Verma  2019-11-30      60   59843  1006      Priya Iyer
# 6   1007     Vijay Singh  2022-07-08      10    1000  1007     Arjun Singh
# 7   1008     Ananya Iyer  2021-03-15      20   74625  1008      Neha Verma
# 8   1009    Manish Joshi  2020-12-19      30   67560  1009   Devansh Desai
# 9   1010     Simran Kaur  2023-01-11      40   68902  1010    Ananya Joshi
# 10  1011    Rajesh Mehta  2021-09-01      50   62497  1011    Rohan Kapoor
# ...
