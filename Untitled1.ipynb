# %%
import pandas as pd

# %%
df1=pd.read_csv("file1.csv")

# %%
df1
# Out:
#    eno   ename
# 0    1   James
# 1    2   Coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
df2=pd.read_csv("file2.csv")

# %%
df2
# Out:
#    eno   ename  Salary
# 0    1   James    1000
# 1    2   Coles    2000
# 2    3  Thomas    3400
# 3    6  Mayank    4500
# 4    7   Akash    1200

# %%
df1
# Out:
#    eno   ename
# 0    1   James
# 1    2   Coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
mg=df1.merge(df2, on=['eno','ename'],how='inner',)

# %%
mg
# Out:
#    eno   ename  Salary
# 0    1   James    1000
# 1    2   Coles    2000
# 2    3  Thomas    3400

# %%
df_ans=pd.concat([df1,df2], axis=1)

# %%
df_ans
# Out:
#    eno   ename  eno   ename  Salary
# 0    1   James    1   James    1000
# 1    2   Coles    2   Coles    2000
# 2    3  Thomas    3  Thomas    3400
# 3    4  Mayank    6  Mayank    4500
# 4    5   Akash    7   Akash    1200

# %%
df
# Out:
#    eno   ename
# 0    1   James
# 1    2   Coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
df.iloc[0:5]
# Out:
#    eno   ename
# 0    1   James
# 1    2   Coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
df1
# Out:
#    eno   ename
# 0    1   James
# 1    2   Coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
df2
# Out:
#    eno   ename  Salary
# 0    1   James    1000
# 1    2   Coles    2000
# 2    3  Thomas    3400
# 3    6  Mayank    4500
# 4    7   Akash    1200

# %%
df1.compare(df2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10064\871738017.py in ?()
# ----> 1 df1.compare(df2)
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py in ?(self, other, align_axis, keep_shape, keep_equal, result_names)
#    8589         keep_shape: bool = False,
#    8590         keep_equal: bool = False,
#    8591         result_names: Suffixes = ("self", "other"),
#    8592     ) -> DataFrame:
# -> 8593         return super().compare(
#    8594             other=other,
#    8595             align_axis=align_axis,
#    8596             keep_shape=keep_shape,
#
# ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\generic.py in ?(self, other, align_axis, keep_shape, keep_equal, result_names)
#   10117             raise TypeError(
# ...

# %%
df
# Out:
#    eno   ename
# 0    1   James
# 1    2   Coles
# 2    3  Thomas
# 3    4  Mayank
# 4    5   Akash

# %%
import pandas as pd

# %%
df=pd.read_csv("emp.csv")

# %%
df
# Out:
#      eno               ename         doj  deptno  salary
# 0   1001        Arjun Sharma  2022-01-15      10    1000
# 1   1002         Priya Patel  2023-03-22      20   67387
# 2   1003          Ravi Kumar  2021-05-10      30   70421
# 3   1004         Sneha Gupta  2020-08-25      40   68902
# 4   1005          Anil Reddy  2024-02-13      50   78005
# 5   1006          Neha Verma  2019-11-30      60   59843
# 6   1007         Vijay Singh  2022-07-08      10    1000
# 7   1008         Ananya Iyer  2021-03-15      20   74625
# 8   1009        Manish Joshi  2020-12-19      30   67560
# 9   1010         Simran Kaur  2023-01-11      40   68902
# 10  1011        Rajesh Mehta  2021-09-01      50   62497
# 11  1012       Deepika Desai  2020-06-10      60   70179
# 12  1013      Shivani Sharma  2022-09-13      10   74363
# 13  1014         Harish Nair  2023-04-01      20   61487
# 14  1015         Komal Yadav  2021-11-23      30   61894
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [eno, ename, doj, deptno, salary]
# Index: []

# %%
df.isnull().count()
# Out:
# eno       50
# ename     50
# doj       50
# deptno    50
# salary    50
# dtype: int64

# %%
df[(df.salary>50000) & (df.deptno==10)]
# Out:
#      eno           ename         doj  deptno  salary
# 12  1013  Shivani Sharma  2022-09-13      10   74363
# 20  1021  Prakash Pillai  2022-12-11      10   73569
# 26  1027   Harshit Kumar  2022-08-16      10   66535
# 32  1033     Suresh Jain  2021-12-01      10   69234
# 38  1039      Ajit Reddy  2022-04-18      10   69399
# 44  1045    Pankaj Joshi  2022-06-10      10   70445

# %%
df1.merge(df2,
             indicator=True,
             how="left").query('_merge=="left_only"')
# Out:
#    eno   ename  Salary     _merge
# 3    4  Mayank     NaN  left_only
# 4    5   Akash     NaN  left_only

# %%
df["deptno"].nunique()
# Out:
# 6
